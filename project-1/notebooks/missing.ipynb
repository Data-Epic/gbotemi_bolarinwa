# %%
import pandas as pd
import numpy as np
import gspread
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings('ignore')

# %%
gc = gspread.service_account(filename='secret.json')

# %%
file = "https://docs.google.com/spreadsheets/d/1SUlcukpgxf6pfFQbj6DKQZXSlOhyBOSuBdbmQ2ZbhTM/edit?usp=sharing"

# %%
sh = gc.open_by_url(file)

# %%
sh
# Out:
# <Spreadsheet 'Intermediate_Task' id:1SUlcukpgxf6pfFQbj6DKQZXSlOhyBOSuBdbmQ2ZbhTM>

# %%
worksheet = sh.get_worksheet(0)

# %%
sh.worksheets()
# Out:
# [<Worksheet 'missing_data' id:327494290>,
#  <Worksheet 'inconsistent_data' id:1520648174>]

# %%
data = pd.DataFrame(worksheet.get_all_records())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15364 entries, 0 to 15363
# Data columns (total 43 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Permit Number                           15364 non-null  object
#  1   Permit Type                             15364 non-null  int64
#  2   Permit Type Definition                  15364 non-null  object
#  3   Permit Creation Date                    15364 non-null  object
#  4   Block                                   15364 non-null  object
#  5   Lot                                     15364 non-null  object
#  6   Street Number                           15364 non-null  int64
#  7   Street Number Suffix                    15364 non-null  object
#  8   Street Name                             15364 non-null  object
#  9   Street Suffix                           15364 non-null  object
#  10  Unit                                    15364 non-null  object
#  11  Unit Suffix                             15364 non-null  object
#  12  Description                             15364 non-null  object
#  13  Current Status                          15364 non-null  object
#  14  Current Status Date                     15364 non-null  object
#  15  Filed Date                              15364 non-null  object
#  16  Issued Date                             15364 non-null  object
#  17  Completed Date                          15364 non-null  object
#  18  First Construction Document Date        15364 non-null  object
#  19  Structural Notification                 15364 non-null  object
#  20  Number of Existing Stories              15364 non-null  object
#  21  Number of Proposed Stories              15364 non-null  object
#  22  Voluntary Soft-Story Retrofit           15364 non-null  object
#  23  Fire Only Permit                        15364 non-null  object
#  24  Permit Expiration Date                  15364 non-null  object
#  25  Estimated Cost                          15364 non-null  object
#  26  Revised Cost                            15364 non-null  object
#  27  Existing Use                            15364 non-null  object
#  28  Existing Units                          15364 non-null  object
#  29  Proposed Use                            15364 non-null  object
#  30  Proposed Units                          15364 non-null  object
#  31  Plansets                                15364 non-null  object
#  32  TIDF Compliance                         15364 non-null  object
#  33  Existing Construction Type              15364 non-null  object
#  34  Existing Construction Type Description  15364 non-null  object
#  35  Proposed Construction Type              15364 non-null  object
#  36  Proposed Construction Type Description  15364 non-null  object
#  37  Site Permit                             15364 non-null  object
#  38  Supervisor District                     15364 non-null  object
#  39  Neighborhoods - Analysis Boundaries     15364 non-null  object
#  40  Zipcode                                 15364 non-null  object
#  41  Location                                15364 non-null  object
#  42  Record ID                               15364 non-null  float64
# dtypes: float64(1), int64(2), object(40)
# memory usage: 5.0+ MB

# %%
data.shape
# Out:
# (15364, 43)

# %%
data.head()
# Out:
#     Permit Number  Permit Type            Permit Type Definition  \
# 0  201505000000.0            4                      sign - erect
# 1  201604000000.0            4                      sign - erect
# 2  201605000000.0            3  additions alterations or repairs
# 3  201611000000.0            8            otc alterations permit
# 4  201611000000.0            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015   326   23            140
# 1           04/19/2016   306    7            440
# 2           05/27/2016   595  203           1647
# 3           11/07/2016   156   11           1230
# 4           11/28/2016   342    1            950
#
#   Street Name Street Suffix Unit Unit Suffix  \
# 0       Ellis            St
# 1       Geary            St    0
# 2     Pacific            Av
# 3     Pacific            Av    0
# 4      Market            St
#
#                                          Description Current Status  \
# 0  ground fl facade: to erect illuminated, electr...        expired
# 1            remove (e) awning and associated signs.         issued
# 2                    installation of separating wall      withdrawn
# 3           repair dryrot & stucco at front of bldg.       complete
# 4  demolish retail/office/commercial 3-story buil...         issued
#
#   Current Status Date  Filed Date Issued Date Completed Date  \
# 0          12/21/2017  05/06/2015  11/09/2015
# 1          08/03/2017  04/19/2016  08/03/2017
# 2          09/26/2017  05/27/2016
# 3          07/24/2017  11/07/2016  07/18/2017     07/24/2017
# 4          12/01/2017  11/28/2016  12/01/2017
#
#   First Construction Document Date Structural Notification  \
# 0                       11/09/2015
# 1                       08/03/2017
# 2
# 3                       07/18/2017
# 4                       11/20/2017
#
#   Number of Existing Stories Number of Proposed Stories  \
# 0                          6
# 1                          7
# 2                          6                          6
# 3                          2                          2
# 4                          3
#
#   Voluntary Soft-Story Retrofit Fire Only Permit Permit Expiration Date  \
# 0                                                            11/03/2016
# 1                                                            12/03/2017
# 2
# 3                                                            07/13/2018
# 4                                                            12/01/2018
#
#   Estimated Cost Revised Cost         Existing Use Existing Units  \
# 0           4000         4000  tourist hotel/motel            143
# 1              1          500  tourist hotel/motel
# 2          20000                      retail sales             39
# 3           2000         2000    1 family dwelling              1
# 4         100000       100000         retail sales
#
#         Proposed Use Proposed Units Plansets TIDF Compliance  \
# 0                                          2
# 1                                          2
# 2       retail sales             39        2
# 3  1 family dwelling              1        2
# 4                                          2
#
#   Existing Construction Type Existing Construction Type Description  \
# 0                          3                          constr type 3
# 1                          3                          constr type 3
# 2                          1                          constr type 1
# 3                          5                         wood frame (5)
# 4                          3                          constr type 3
#
#   Proposed Construction Type Proposed Construction Type Description  \
# 0
# 1
# 2                          1                          constr type 1
# 3                          5                         wood frame (5)
# 4
#
#   Site Permit Supervisor District Neighborhoods - Analysis Boundaries Zipcode  \
# 0                               3                          Tenderloin   94102
# 1                               3                          Tenderloin   94102
# 2                               3                        Russian Hill   94109
# 3                               3                            Nob Hill   94109
# 4                               6                          Tenderloin   94102
#
#                                     Location     Record ID
# 0  (37.785719256680785, -122.40852313194863)  1.380610e+12
# 1   (37.78733980600732, -122.41063199757738)  1.420160e+12
# 2    (37.7946573324287, -122.42232562979227)  1.424860e+12
# 3   (37.79595867909168, -122.41557405519474)  1.443570e+12
# 4   (37.78315261897309, -122.40950883997789)  1.445480e+11

# %%
data = data.replace("", np.nan) #replace empty strings with numpy nan values

# %%
(data.isna().sum() / len(data)) * 100
# Out:
# Permit Number                               0.000000
# Permit Type                                 0.000000
# Permit Type Definition                      0.000000
# Permit Creation Date                        0.000000
# Block                                       0.000000
# Lot                                         0.000000
# Street Number                               0.000000
# Street Number Suffix                       98.958605
# Street Name                                 0.000000
# Street Suffix                               1.262692
# Unit                                       86.025775
# Unit Suffix                                98.834939
# Description                                 0.162718
# Current Status                              0.000000
# Current Status Date                         0.000000
# Filed Date                                  0.000000
# Issued Date                                 4.133038
# Completed Date                             40.581880
# First Construction Document Date            4.159073
# Structural Notification                    96.953918
# Number of Existing Stories                 20.756313
# Number of Proposed Stories                 22.038532
# Voluntary Soft-Story Retrofit              99.928404
# Fire Only Permit                           90.751106
# Permit Expiration Date                     22.520177
# Estimated Cost                             18.790680
# Revised Cost                                1.607654
# Existing Use                               20.164020
# Existing Units                             25.494663
# Proposed Use                               21.693569
# Proposed Units                             26.152044
# Plansets                                   18.582400
# TIDF Compliance                           100.000000
# Existing Construction Type                 21.088258
# Existing Construction Type Description     21.088258
# Proposed Construction Type                 22.240302
# Proposed Construction Type Description     22.240302
# Site Permit                                98.073418
# Supervisor District                         0.774538
# Neighborhoods - Analysis Boundaries         0.774538
# Zipcode                                     0.774538
# Location                                    0.768029
# Record ID                                   0.000000
# dtype: float64

# %%
# Drop missing data that are over 60%   
# https://www.sciencedirect.com/science/article/pii/S0895435618308710#:~:text=Statistical%20guidance%20articles%20have%20stated,18%5D%2C%20%5B19%5D.

# %%
large_missing_dict = ((data.isna().sum() / len(data)) * 100).to_dict()

# %%
missing_cols = [idx for idx in large_missing_dict.keys() if large_missing_dict.get(idx) > 60]

# %%
missing_cols
# Out:
# ['Street Number Suffix',
#  'Unit',
#  'Unit Suffix',
#  'Structural Notification',
#  'Voluntary Soft-Story Retrofit',
#  'Fire Only Permit',
#  'TIDF Compliance',
#  'Site Permit']

# %%
data = data.drop(columns=missing_cols)

# %%
small_missing_dict = ((data.isna().sum() / len(data)) * 100).to_dict()

# %%
small_missing_cols = [idx for idx in small_missing_dict.keys() if small_missing_dict.get(idx) > 0]

# %%
data[small_missing_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15364 entries, 0 to 15363
# Data columns (total 23 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Street Suffix                           15170 non-null  object
#  1   Description                             15339 non-null  object
#  2   Issued Date                             14729 non-null  object
#  3   Completed Date                          9129 non-null   object
#  4   First Construction Document Date        14725 non-null  object
#  5   Number of Existing Stories              12175 non-null  float64
#  6   Number of Proposed Stories              11978 non-null  float64
#  7   Permit Expiration Date                  11904 non-null  object
#  8   Estimated Cost                          12477 non-null  float64
#  9   Revised Cost                            15117 non-null  float64
#  10  Existing Use                            12266 non-null  object
#  11  Existing Units                          11447 non-null  float64
#  12  Proposed Use                            12031 non-null  object
#  13  Proposed Units                          11346 non-null  float64
#  14  Plansets                                12509 non-null  float64
#  15  Existing Construction Type              12124 non-null  float64
#  16  Existing Construction Type Description  12124 non-null  object
#  17  Proposed Construction Type              11947 non-null  float64
#  18  Proposed Construction Type Description  11947 non-null  object
#  19  Supervisor District                     15245 non-null  float64
#  20  Neighborhoods - Analysis Boundaries     15245 non-null  object
#  21  Zipcode                                 15245 non-null  float64
#  22  Location                                15246 non-null  object
# dtypes: float64(11), object(12)
# memory usage: 2.7+ MB

# %%
mode_existing_storries = data['Number of Existing Stories'].mode()

fig, ax = plt.subplots()
sns.distplot(data['Number of Existing Stories'], ax=ax, label="green")
sns.distplot(data['Number of Existing Stories'].fillna(mode_existing_storries), ax=ax, label="yellow")
plt.show()

# %%
mode_existing_storries = data[small_missing_cols[15]].mode()

fig, ax = plt.subplots()
sns.distplot(data[small_missing_cols[15]], ax=ax, label="green")
sns.distplot(data[small_missing_cols[15]].fillna(mode_existing_storries), ax=ax, label="yellow")
plt.show()

# %%
data.duplicated().sum()
# Out:
# 30

# %%
data = data.drop_duplicates(keep="first") # drop duplicated data

# %%
data[small_missing_cols]
# Out:
#       Street Suffix                                        Description  \
# 0                St  ground fl facade: to erect illuminated, electr...
# 1                St            remove (e) awning and associated signs.
# 2                Av                    installation of separating wall
# 3                Av           repair dryrot & stucco at front of bldg.
# 4                St  demolish retail/office/commercial 3-story buil...
# ...             ...                                                ...
# 15359            St  install finishing plumbing, finish electrical,...
# 15360            St  revision to 201208288466 to add a toilet in th...
# 15361            St  revision to 201208288466 to add a toilet in th...
# 15362            St  interior renovation unit #2334, new kitchen fi...
# 15363            St                                street space permit
#
#       Issued Date Completed Date First Construction Document Date  \
# 0      11/09/2015            NaN                       11/09/2015
# 1      08/03/2017            NaN                       08/03/2017
# 2             NaN            NaN                              NaN
# 3      07/18/2017     07/24/2017                       07/18/2017
# 4      12/01/2017            NaN                       11/20/2017
# ...           ...            ...                              ...
# 15359  06/11/2013            NaN                       06/11/2013
# 15360  06/18/2013     08/30/2013                       06/18/2013
# 15361  06/18/2013     08/30/2013                       06/18/2013
# 15362  06/11/2013     08/05/2013                       06/11/2013
# 15363  06/11/2013            NaN                       06/11/2013
#
#        Number of Existing Stories  Number of Proposed Stories  \
# 0                             6.0                         NaN
# 1                             7.0                         NaN
# 2                             6.0                         6.0
# 3                             2.0                         2.0
# 4                             3.0                         NaN
# ...                           ...                         ...
# 15359                         2.0                         2.0
# 15360                         2.0                         2.0
# 15361                         2.0                         2.0
# 15362                         2.0                         2.0
# 15363                         NaN                         NaN
#
#       Permit Expiration Date  Estimated Cost  Revised Cost  \
# 0                 11/03/2016          4000.0        4000.0
# 1                 12/03/2017             1.0         500.0
# 2                        NaN         20000.0           NaN
# 3                 07/13/2018          2000.0        2000.0
# 4                 12/01/2018        100000.0      100000.0
# ...                      ...             ...           ...
# 15359             06/06/2014          8000.0       28000.0
# 15360             06/13/2014          2000.0        2000.0
# 15361             06/13/2014          2000.0        2000.0
# 15362             06/06/2014         26000.0       26000.0
# 15363                    NaN             NaN           1.0
#
#               Existing Use  Existing Units       Proposed Use  Proposed Units  \
# 0      tourist hotel/motel           143.0                NaN             NaN
# 1      tourist hotel/motel             NaN                NaN             NaN
# 2             retail sales            39.0       retail sales            39.0
# 3        1 family dwelling             1.0  1 family dwelling             1.0
# 4             retail sales             NaN                NaN             NaN
# ...                    ...             ...                ...             ...
# 15359    1 family dwelling             1.0  1 family dwelling             1.0
# 15360    2 family dwelling             2.0  2 family dwelling             2.0
# 15361    2 family dwelling             2.0  2 family dwelling             2.0
# 15362           apartments             8.0         apartments             8.0
# 15363                  NaN             NaN                NaN             NaN
#
#        Plansets  Existing Construction Type  \
# 0           2.0                         3.0
# 1           2.0                         3.0
# 2           2.0                         1.0
# 3           2.0                         5.0
# 4           2.0                         3.0
# ...         ...                         ...
# 15359       0.0                         5.0
# 15360       2.0                         5.0
# 15361       2.0                         5.0
# 15362       0.0                         5.0
# 15363       NaN                         NaN
#
#       Existing Construction Type Description  Proposed Construction Type  \
# 0                              constr type 3                         NaN
# 1                              constr type 3                         NaN
# 2                              constr type 1                         1.0
# 3                             wood frame (5)                         5.0
# 4                              constr type 3                         NaN
# ...                                      ...                         ...
# 15359                         wood frame (5)                         5.0
# 15360                         wood frame (5)                         5.0
# 15361                         wood frame (5)                         5.0
# 15362                         wood frame (5)                         5.0
# 15363                                    NaN                         NaN
#
#       Proposed Construction Type Description  Supervisor District  \
# 0                                        NaN                  3.0
# 1                                        NaN                  3.0
# 2                              constr type 1                  3.0
# 3                             wood frame (5)                  3.0
# 4                                        NaN                  6.0
# ...                                      ...                  ...
# 15359                         wood frame (5)                 11.0
# 15360                         wood frame (5)                  9.0
# 15361                         wood frame (5)                  9.0
# 15362                         wood frame (5)                 10.0
# 15363                                    NaN                  6.0
#
#       Neighborhoods - Analysis Boundaries  Zipcode  \
# 0                              Tenderloin  94102.0
# 1                              Tenderloin  94102.0
# 2                            Russian Hill  94109.0
# 3                                Nob Hill  94109.0
# 4                              Tenderloin  94102.0
# ...                                   ...      ...
# 15359          Oceanview/Merced/Ingleside  94112.0
# 15360                             Mission  94110.0
# 15361                             Mission  94110.0
# 15362                        Potrero Hill  94107.0
# 15363                     South of Market  94103.0
#
#                                         Location
# 0      (37.785719256680785, -122.40852313194863)
# 1       (37.78733980600732, -122.41063199757738)
# 2        (37.7946573324287, -122.42232562979227)
# 3       (37.79595867909168, -122.41557405519474)
# 4       (37.78315261897309, -122.40950883997789)
# ...                                          ...
# 15359    (37.7143177382725, -122.45793648914099)
# 15360    (37.7583635958755, -122.42012861020109)
# 15361    (37.7583635958755, -122.42012861020109)
# 15362  (37.752135529825054, -122.40206132582264)
# 15363  (37.777338241377954, -122.41391079039403)
#
# [15334 rows x 23 columns]

# %% [markdown]
# Todo: Convert data to datatime format
#
# date col = ["Issued Date", "Completed Date", "First Construction Document Date", "Permit Expiration Date"]

# %%
data['Zipcode'].isna().sum()
# Out:
# 119

# %%
data[data['Location'].isna() & data['Zipcode'].isna()].shape
# Out:
# (118, 35)

# %% [markdown]
# drop empty zipcode, Neighborhoods - Analysis Boundaries and location data if empty.

# %%
data['Description'] = data['Description'].fillna("Unknown")

# %%
data['Proposed Use'].value_counts()
# Out:
# Proposed Use
# 1 family dwelling      3757
# apartments             2799
# office                 1911
# 2 family dwelling      1699
# retail sales            457
#                        ...
# dance hall                1
# library                   1
# storage tanks             1
# day care home lt 7        1
# chemical processing       1
# Name: count, Length: 69, dtype: int64

# %%
from miceforest import ImputationKernel

# %%
mice_kernel = ImputationKernel(data=data, save_all_iterations=True, random_state=42)
mice_kernel.mice(2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/gbotemi/Documents/gbotemi_bolarinwa/gspread-project/missing.ipynb Cell 34 line 1
# ----> <a href='vscode-notebook-cell:/home/gbotemi/Documents/gbotemi_bolarinwa/gspread-project/missing.ipynb#Y116sZmlsZQ%3D%3D?line=0'>1</a> mice_kernel = ImputationKernel(data=data, save_all_iterations=True, random_state=42)
#       <a href='vscode-notebook-cell:/home/gbotemi/Documents/gbotemi_bolarinwa/gspread-project/missing.ipynb#Y116sZmlsZQ%3D%3D?line=1'>2</a> mice_kernel.mice(2)
#
# File ~/miniconda3/envs/gspread/lib/python3.12/site-packages/miceforest/ImputationKernel.py:240, in ImputationKernel.__init__(self, data, datasets, variable_schema, imputation_order, train_nonmissing, mean_match_candidates, data_subset, mean_match_function, categorical_feature, initialization, save_all_iterations, save_models, copy_data, random_state)
#     222 def __init__(
#     223     self,
#     224     data,
#    (...)
#     237     random_state=None,
#     238 ):
# --> 240     super().__init__(
#     241         impute_data=data,
#     242         datasets=datasets,
#     243         variable_schema=variable_schema,
#     244         imputation_order=imputation_order,
#     245         train_nonmissing=train_nonmissing,
#     246         categorical_feature=categorical_feature,
#     247         save_all_iterations=save_all_iterations,
#     248         copy_data=copy_data,
#     249     )
#     251     self.initialization = initialization
#     252     self.train_nonmissing = train_nonmissing
#
# File ~/miniconda3/envs/gspread/lib/python3.12/site-packages/miceforest/ImputedData.py:104, in ImputedData.__init__(self, impute_data, datasets, variable_schema, imputation_order, train_nonmissing, categorical_feature, save_all_iterations, copy_data)
#     101 data_shape = self.working_data.shape
#     103 if any([x.name == "object" for x in pd_dtypes_orig]):
# --> 104     raise ValueError(
#     105         "Please convert object columns to categorical or some numeric type."
#     106     )
#     108 # Assume categories are set dtypes.
#     109 if categorical_feature == "auto":
#
# ValueError: Please convert object columns to categorical or some numeric type.

# %%
#imputing

impute_data = data.copy()

# %%
impute_col = impute_data.columns[impute_data.isnull().any()]

# %%
# impute_data.loc[impute_data[target].isnull(), col_missing.to_list()]

# %%
from lightgbm import LGBMClassifier

# %%
for target in impute_col:

    col_missing = impute_data[impute_col].columns.difference([target])
    
    known_data = impute_data.loc[impute_data[target].notnull(), col_missing.to_list() + [target]]
    missing_data = impute_data.loc[impute_data[target].isnull(), col_missing.to_list()]
    # print(missing_data.head())

    X_known_data = known_data[col_missing]
    y_known_data = known_data[target]
    X_missing_data = missing_data[col_missing]

    regression_model = LGBMClassifier()

    regression_model.fit(X_known_data, y_known_data)
    preds = regression_model.predict(X_missing_data)
    impute_data.loc[impute_data[target].isnull(), target] = preds
    # print(col_missing.to_list() + [target])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/gbotemi/Documents/gbotemi_bolarinwa/gspread-project/missing.ipynb Cell 37 line 1
#      <a href='vscode-notebook-cell:/home/gbotemi/Documents/gbotemi_bolarinwa/gspread-project/missing.ipynb#X65sZmlsZQ%3D%3D?line=10'>11</a> X_missing_data = missing_data[col_missing]
#      <a href='vscode-notebook-cell:/home/gbotemi/Documents/gbotemi_bolarinwa/gspread-project/missing.ipynb#X65sZmlsZQ%3D%3D?line=12'>13</a> regression_model = LGBMClassifier()
# ---> <a href='vscode-notebook-cell:/home/gbotemi/Documents/gbotemi_bolarinwa/gspread-project/missing.ipynb#X65sZmlsZQ%3D%3D?line=14'>15</a> regression_model.fit(X_known_data, y_known_data)
#      <a href='vscode-notebook-cell:/home/gbotemi/Documents/gbotemi_bolarinwa/gspread-project/missing.ipynb#X65sZmlsZQ%3D%3D?line=15'>16</a> preds = regression_model.predict(X_missing_data)
#      <a href='vscode-notebook-cell:/home/gbotemi/Documents/gbotemi_bolarinwa/gspread-project/missing.ipynb#X65sZmlsZQ%3D%3D?line=16'>17</a> impute_data.loc[impute_data[target].isnull(), target] = preds
#
# File ~/miniconda3/envs/gspread/lib/python3.12/site-packages/lightgbm/sklearn.py:1142, in LGBMClassifier.fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#    1139         else:
#    1140             valid_sets.append((valid_x, self._le.transform(valid_y)))
# -> 1142 super().fit(
#    1143     X,
#    1144     _y,
#    1145     sample_weight=sample_weight,
#    1146     init_score=init_score,
#    1147     eval_set=valid_sets,
#    1148     eval_names=eval_names,
#    1149     eval_sample_weight=eval_sample_weight,
#    1150     eval_class_weight=eval_class_weight,
#    1151     eval_init_score=eval_init_score,
#    1152     eval_metric=eval_metric,
#    1153     feature_name=feature_name,
#    1154     categorical_feature=categorical_feature,
#    1155     callbacks=callbacks,
#    1156     init_model=init_model
#    1157 )
#    1158 return self
#
# File ~/miniconda3/envs/gspread/lib/python3.12/site-packages/lightgbm/sklearn.py:842, in LGBMModel.fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, feature_name, categorical_feature, callbacks, init_model)
#     839 evals_result: _EvalResultDict = {}
#     840 callbacks.append(record_evaluation(evals_result))
# --> 842 self._Booster = train(
#     843     params=params,
#     844     train_set=train_set,
#     845     num_boost_round=self.n_estimators,
#     846     valid_sets=valid_sets,
#     847     valid_names=eval_names,
#     848     feval=eval_metrics_callable,  # type: ignore[arg-type]
#     849     init_model=init_model,
#     850     feature_name=feature_name,
#     851     callbacks=callbacks
#     852 )
#     854 self._evals_result = evals_result
#     855 self._best_iteration = self._Booster.best_iteration
#
# File ~/miniconda3/envs/gspread/lib/python3.12/site-packages/lightgbm/engine.py:255, in train(params, train_set, num_boost_round, valid_sets, valid_names, feval, init_model, feature_name, categorical_feature, keep_training_booster, callbacks)
#     253 # construct booster
#     254 try:
# --> 255     booster = Booster(params=params, train_set=train_set)
#     256     if is_valid_contain_train:
#     257         booster.set_train_data_name(train_data_name)
#
# File ~/miniconda3/envs/gspread/lib/python3.12/site-packages/lightgbm/basic.py:3200, in Booster.__init__(self, params, train_set, model_file, model_str)
#    3193     self.set_network(
#    3194         machines=machines,
#    3195         local_listen_port=params["local_listen_port"],
#    3196         listen_time_out=params.get("time_out", 120),
#    3197         num_machines=params["num_machines"]
#    3198     )
#    3199 # construct booster object
# -> 3200 train_set.construct()
#    3201 # copy the parameters from train_set
#    3202 params.update(train_set.get_params())
#
# File ~/miniconda3/envs/gspread/lib/python3.12/site-packages/lightgbm/basic.py:2276, in Dataset.construct(self)
#    2269             self._set_init_score_by_predictor(
#    2270                 predictor=self._predictor,
#    2271                 data=self.data,
#    2272                 used_indices=used_indices
#    2273             )
#    2274 else:
#    2275     # create train
# -> 2276     self._lazy_init(data=self.data, label=self.label, reference=None,
#    2277                     weight=self.weight, group=self.group,
#    2278                     init_score=self.init_score, predictor=self._predictor,
#    2279                     feature_name=self.feature_name, categorical_feature=self.categorical_feature,
#    2280                     params=self.params, position=self.position)
#    2281 if self.free_raw_data:
#    2282     self.data = None
#
# File ~/miniconda3/envs/gspread/lib/python3.12/site-packages/lightgbm/basic.py:1861, in Dataset._lazy_init(self, data, label, reference, weight, group, init_score, predictor, feature_name, categorical_feature, params, position)
#    1859     categorical_feature = reference.categorical_feature
#    1860 if isinstance(data, pd_DataFrame):
# -> 1861     data, feature_name, categorical_feature, self.pandas_categorical = _data_from_pandas(
#    1862         data=data,
#    1863         feature_name=feature_name,
#    1864         categorical_feature=categorical_feature,
#    1865         pandas_categorical=self.pandas_categorical
#    1866     )
#    1868 # process for args
#    1869 params = {} if params is None else params
#
# File ~/miniconda3/envs/gspread/lib/python3.12/site-packages/lightgbm/basic.py:703, in _data_from_pandas(data, feature_name, categorical_feature, pandas_categorical)
#     700     categorical_feature = list(categorical_feature)  # type: ignore[assignment]
#     702 # get numpy representation of the data
# --> 703 _check_for_bad_pandas_dtypes(data.dtypes)
#     704 df_dtypes = [dtype.type for dtype in data.dtypes]
#     705 df_dtypes.append(np.float32)  # so that the target dtype considers floats
#
# File ~/miniconda3/envs/gspread/lib/python3.12/site-packages/lightgbm/basic.py:666, in _check_for_bad_pandas_dtypes(pandas_dtypes_series)
#     660 bad_pandas_dtypes = [
#     661     f'{column_name}: {pandas_dtype}'
#     662     for column_name, pandas_dtype in pandas_dtypes_series.items()
#     663     if not _is_allowed_numpy_dtype(pandas_dtype.type)
#     664 ]
#     665 if bad_pandas_dtypes:
# --> 666     raise ValueError('pandas dtypes must be int, float or bool.\n'
#     667                      f'Fields with bad pandas dtypes: {", ".join(bad_pandas_dtypes)}')
#
# ValueError: pandas dtypes must be int, float or bool.
# Fields with bad pandas dtypes: Completed Date: object, Existing Construction Type Description: object, Existing Use: object, First Construction Document Date: object, Issued Date: object, Location: object, Neighborhoods - Analysis Boundaries: object, Permit Expiration Date: object, Proposed Construction Type Description: object, Proposed Use: object

# %%
t = ['Completed Date', 'Estimated Cost', 'Existing Construction Type', 'Existing Construction Type Description', 'Existing Units', 'Existing Use', 'First Construction Document Date', 'Issued Date', 'Location', 'Neighborhoods - Analysis Boundaries', 'Number of Existing Stories', 'Number of Proposed Stories', 'Permit Expiration Date', 'Plansets', 'Proposed Construction Type', 'Proposed Construction Type Description', 'Proposed Units', 'Proposed Use', 'Revised Cost', 'Supervisor District', 'Zipcode', 'Street Suffix']

# %%
impute_data[t].notnull()
# Out:
#        Completed Date  Estimated Cost  Existing Construction Type  \
# 0               False            True                        True
# 1               False            True                        True
# 2               False            True                        True
# 3                True            True                        True
# 4               False            True                        True
# ...               ...             ...                         ...
# 15359           False            True                        True
# 15360            True            True                        True
# 15361            True            True                        True
# 15362            True            True                        True
# 15363           False           False                       False
#
#        Existing Construction Type Description  Existing Units  Existing Use  \
# 0                                        True            True          True
# 1                                        True           False          True
# 2                                        True            True          True
# 3                                        True            True          True
# 4                                        True           False          True
# ...                                       ...             ...           ...
# 15359                                    True            True          True
# 15360                                    True            True          True
# 15361                                    True            True          True
# 15362                                    True            True          True
# 15363                                   False           False         False
#
#        First Construction Document Date  Issued Date  Location  \
# 0                                  True         True      True
# 1                                  True         True      True
# 2                                 False        False      True
# 3                                  True         True      True
# 4                                  True         True      True
# ...                                 ...          ...       ...
# 15359                              True         True      True
# 15360                              True         True      True
# 15361                              True         True      True
# 15362                              True         True      True
# 15363                              True         True      True
#
#        Neighborhoods - Analysis Boundaries  Number of Existing Stories  \
# 0                                     True                        True
# 1                                     True                        True
# 2                                     True                        True
# 3                                     True                        True
# 4                                     True                        True
# ...                                    ...                         ...
# 15359                                 True                        True
# 15360                                 True                        True
# 15361                                 True                        True
# 15362                                 True                        True
# 15363                                 True                       False
#
#        Number of Proposed Stories  Permit Expiration Date  Plansets  \
# 0                           False                    True      True
# 1                           False                    True      True
# 2                            True                   False      True
# 3                            True                    True      True
# 4                           False                    True      True
# ...                           ...                     ...       ...
# 15359                        True                    True      True
# 15360                        True                    True      True
# 15361                        True                    True      True
# 15362                        True                    True      True
# 15363                       False                   False     False
#
#        Proposed Construction Type  Proposed Construction Type Description  \
# 0                           False                                   False
# 1                           False                                   False
# 2                            True                                    True
# 3                            True                                    True
# 4                           False                                   False
# ...                           ...                                     ...
# 15359                        True                                    True
# 15360                        True                                    True
# 15361                        True                                    True
# 15362                        True                                    True
# 15363                       False                                   False
#
#        Proposed Units  Proposed Use  Revised Cost  Supervisor District  \
# 0               False         False          True                 True
# 1               False         False          True                 True
# 2                True          True         False                 True
# 3                True          True          True                 True
# 4               False         False          True                 True
# ...               ...           ...           ...                  ...
# 15359            True          True          True                 True
# 15360            True          True          True                 True
# 15361            True          True          True                 True
# 15362            True          True          True                 True
# 15363           False         False          True                 True
#
#        Zipcode  Street Suffix
# 0         True           True
# 1         True           True
# 2         True           True
# 3         True           True
# 4         True           True
# ...        ...            ...
# 15359     True           True
# 15360     True           True
# 15361     True           True
# 15362     True           True
# 15363     True           True
#
# [15334 rows x 22 columns]

# %%
impute_data.loc[impute_data[t].notnull(), t]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/gbotemi/Documents/gbotemi_bolarinwa/gspread-project/missing.ipynb Cell 38 line 1
# ----> <a href='vscode-notebook-cell:/home/gbotemi/Documents/gbotemi_bolarinwa/gspread-project/missing.ipynb#Y104sZmlsZQ%3D%3D?line=0'>1</a> impute_data.loc[impute_data[t].notnull(), t]
#
# File ~/miniconda3/envs/gspread/lib/python3.12/site-packages/pandas/core/indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# File ~/miniconda3/envs/gspread/lib/python3.12/site-packages/pandas/core/indexing.py:1337, in _LocIndexer._getitem_tuple(self, tup)
#    1335 # ugly hack for GH #836
#    1336 if self._multi_take_opportunity(tup):
# -> 1337     return self._multi_take(tup)
#    1339 return self._getitem_tuple_same_dim(tup)
#
# File ~/miniconda3/envs/gspread/lib/python3.12/site-packages/pandas/core/indexing.py:1289, in _LocIndexer._multi_take(self, tup)
#    1272 """
#    1273 Create the indexers for the passed tuple of keys, and
#    1274 executes the take operation. This allows the take operation to be
#    (...)
#    1285 values: same type as the object being indexed
#    1286 """
#    1287 # GH 836
#    1288 d = {
# -> 1289     axis: self._get_listlike_indexer(key, axis)
#    1290     for (key, axis) in zip(tup, self.obj._AXIS_ORDERS)
#    1291 }
#    1292 return self.obj._reindex_with_indexers(d, copy=True, allow_dups=True)
#
# File ~/miniconda3/envs/gspread/lib/python3.12/site-packages/pandas/core/indexing.py:1520, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1517 ax = self.obj._get_axis(axis)
#    1518 axis_name = self.obj._get_axis_name(axis)
# -> 1520 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1522 return keyarr, indexer
#
# File ~/miniconda3/envs/gspread/lib/python3.12/site-packages/pandas/core/indexes/base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
#    6112     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6114 self._raise_if_missing(keyarr, indexer, axis_name)
#    6116 keyarr = self.take(indexer)
#    6117 if isinstance(key, Index):
#    6118     # GH 42790 - Preserve name from an Index
#
# File ~/miniconda3/envs/gspread/lib/python3.12/site-packages/pandas/core/indexes/base.py:6175, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6173     if use_interval_msg:
#    6174         key = list(key)
# -> 6175     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6177 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6178 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([                                                                                                                        ('C', 'o', 'm', 'p', 'l', 'e', 't', 'e', 'd', ' ', 'D', 'a', 't', 'e'),\n                                                                                                                               ('E', 's', 't', 'i', 'm', 'a', 't', 'e', 'd', ' ', 'C', 'o', 's', 't'),\n                                                                   ('E', 'x', 'i', 's', 't', 'i', 'n', 'g', ' ', 'C', 'o', 'n', 's', 't', 'r', 'u', 'c', 't', 'i', 'o', 'n', ' ', 'T', 'y', 'p', 'e'),\n       ('E', 'x', 'i', 's', 't', 'i', 'n', 'g', ' ', 'C', 'o', 'n', 's', 't', 'r', 'u', 'c', 't', 'i', 'o', 'n', ' ', 'T', 'y', 'p', 'e', ' ', 'D', 'e', 's', 'c', 'r', 'i', 'p', 't', 'i', 'o', 'n'),\n                                                                                                                               ('E', 'x', 'i', 's', 't', 'i', 'n', 'g', ' ', 'U', 'n', 'i', 't', 's'),\n                                                                                                                                         ('E', 'x', 'i', 's', 't', 'i', 'n', 'g', ' ', 'U', 's', 'e'),\n                                     ('F', 'i', 'r', 's', 't', ' ', 'C', 'o', 'n', 's', 't', 'r', 'u', 'c', 't', 'i', 'o', 'n', ' ', 'D', 'o', 'c', 'u', 'm', 'e', 'n', 't', ' ', 'D', 'a', 't', 'e'),\n                                                                                                                                              ('I', 's', 's', 'u', 'e', 'd', ' ', 'D', 'a', 't', 'e'),\n                                                                                                                                                             ('L', 'o', 'c', 'a', 't', 'i', 'o', 'n'),\n                      ('N', 'e', 'i', 'g', 'h', 'b', 'o', 'r', 'h', 'o', 'o', 'd', 's', ' ', '-', ' ', 'A', 'n', 'a', 'l', 'y', 's', 'i', 's', ' ', 'B', 'o', 'u', 'n', 'd', 'a', 'r', 'i', 'e', 's'),\n                                                                   ('N', 'u', 'm', 'b', 'e', 'r', ' ', 'o', 'f', ' ', 'E', 'x', 'i', 's', 't', 'i', 'n', 'g', ' ', 'S', 't', 'o', 'r', 'i', 'e', 's'),\n                                                                   ('N', 'u', 'm', 'b', 'e', 'r', ' ', 'o', 'f', ' ', 'P', 'r', 'o', 'p', 'o', 's', 'e', 'd', ' ', 'S', 't', 'o', 'r', 'i', 'e', 's'),\n                                                                                       ('P', 'e', 'r', 'm', 'i', 't', ' ', 'E', 'x', 'p', 'i', 'r', 'a', 't', 'i', 'o', 'n', ' ', 'D', 'a', 't', 'e'),\n                                                                                                                                                             ('P', 'l', 'a', 'n', 's', 'e', 't', 's'),\n                                                                   ('P', 'r', 'o', 'p', 'o', 's', 'e', 'd', ' ', 'C', 'o', 'n', 's', 't', 'r', 'u', 'c', 't', 'i', 'o', 'n', ' ', 'T', 'y', 'p', 'e'),\n       ('P', 'r', 'o', 'p', 'o', 's', 'e', 'd', ' ', 'C', 'o', 'n', 's', 't', 'r', 'u', 'c', 't', 'i', 'o', 'n', ' ', 'T', 'y', 'p', 'e', ' ', 'D', 'e', 's', 'c', 'r', 'i', 'p', 't', 'i', 'o', 'n'),\n                                                                                                                               ('P', 'r', 'o', 'p', 'o', 's', 'e', 'd', ' ', 'U', 'n', 'i', 't', 's'),\n                                                                                                                                         ('P', 'r', 'o', 'p', 'o', 's', 'e', 'd', ' ', 'U', 's', 'e'),\n                                                                                                                                         ('R', 'e', 'v', 'i', 's', 'e', 'd', ' ', 'C', 'o', 's', 't'),\n                                                                                                      ('S', 'u', 'p', 'e', 'r', 'v', 'i', 's', 'o', 'r', ' ', 'D', 'i', 's', 't', 'r ...

# %%
impute_data.loc[impute_data.notnull(), t]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/gbotemi/Documents/gbotemi_bolarinwa/gspread-project/missing.ipynb Cell 37 line 1
# ----> <a href='vscode-notebook-cell:/home/gbotemi/Documents/gbotemi_bolarinwa/gspread-project/missing.ipynb#X64sZmlsZQ%3D%3D?line=0'>1</a> impute_data.loc[impute_data.notnull(), t]
#
# File ~/miniconda3/envs/gspread/lib/python3.12/site-packages/pandas/core/indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# File ~/miniconda3/envs/gspread/lib/python3.12/site-packages/pandas/core/indexing.py:1337, in _LocIndexer._getitem_tuple(self, tup)
#    1335 # ugly hack for GH #836
#    1336 if self._multi_take_opportunity(tup):
# -> 1337     return self._multi_take(tup)
#    1339 return self._getitem_tuple_same_dim(tup)
#
# File ~/miniconda3/envs/gspread/lib/python3.12/site-packages/pandas/core/indexing.py:1289, in _LocIndexer._multi_take(self, tup)
#    1272 """
#    1273 Create the indexers for the passed tuple of keys, and
#    1274 executes the take operation. This allows the take operation to be
#    (...)
#    1285 values: same type as the object being indexed
#    1286 """
#    1287 # GH 836
#    1288 d = {
# -> 1289     axis: self._get_listlike_indexer(key, axis)
#    1290     for (key, axis) in zip(tup, self.obj._AXIS_ORDERS)
#    1291 }
#    1292 return self.obj._reindex_with_indexers(d, copy=True, allow_dups=True)
#
# File ~/miniconda3/envs/gspread/lib/python3.12/site-packages/pandas/core/indexing.py:1520, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1517 ax = self.obj._get_axis(axis)
#    1518 axis_name = self.obj._get_axis_name(axis)
# -> 1520 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1522 return keyarr, indexer
#
# File ~/miniconda3/envs/gspread/lib/python3.12/site-packages/pandas/core/indexes/base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
#    6112     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6114 self._raise_if_missing(keyarr, indexer, axis_name)
#    6116 keyarr = self.take(indexer)
#    6117 if isinstance(key, Index):
#    6118     # GH 42790 - Preserve name from an Index
#
# File ~/miniconda3/envs/gspread/lib/python3.12/site-packages/pandas/core/indexes/base.py:6175, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6173     if use_interval_msg:
#    6174         key = list(key)
# -> 6175     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6177 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6178 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([                                                                                                                             ('P', 'e', 'r', 'm', 'i', 't', ' ', 'N', 'u', 'm', 'b', 'e', 'r'),\n                                                                                                                                              ('P', 'e', 'r', 'm', 'i', 't', ' ', 'T', 'y', 'p', 'e'),\n                                                                                       ('P', 'e', 'r', 'm', 'i', 't', ' ', 'T', 'y', 'p', 'e', ' ', 'D', 'e', 'f', 'i', 'n', 'i', 't', 'i', 'o', 'n'),\n                                                                                                 ('P', 'e', 'r', 'm', 'i', 't', ' ', 'C', 'r', 'e', 'a', 't', 'i', 'o', 'n', ' ', 'D', 'a', 't', 'e'),\n                                                                                                                                                                            ('B', 'l', 'o', 'c', 'k'),\n                                                                                                                                                                                      ('L', 'o', 't'),\n                                                                                                                                    ('S', 't', 'r', 'e', 'e', 't', ' ', 'N', 'u', 'm', 'b', 'e', 'r'),\n                                                                                                                                              ('S', 't', 'r', 'e', 'e', 't', ' ', 'N', 'a', 'm', 'e'),\n                                                                                                                                    ('S', 't', 'r', 'e', 'e', 't', ' ', 'S', 'u', 'f', 'f', 'i', 'x'),\n                                                                                                                                              ('D', 'e', 's', 'c', 'r', 'i', 'p', 't', 'i', 'o', 'n'),\n                                                                                                                               ('C', 'u', 'r', 'r', 'e', 'n', 't', ' ', 'S', 't', 'a', 't', 'u', 's'),\n                                                                                                      ('C', 'u', 'r', 'r', 'e', 'n', 't', ' ', 'S', 't', 'a', 't', 'u', 's', ' ', 'D', 'a', 't', 'e'),\n                                                                                                                                                   ('F', 'i', 'l', 'e', 'd', ' ', 'D', 'a', 't', 'e'),\n                                                                                                                                              ('I', 's', 's', 'u', 'e', 'd', ' ', 'D', 'a', 't', 'e'),\n                                                                                                                               ('C', 'o', 'm', 'p', 'l', 'e', 't', 'e', 'd', ' ', 'D', 'a', 't', 'e'),\n                                     ('F', 'i', 'r', 's', 't', ' ', 'C', 'o', 'n', 's', 't', 'r', 'u', 'c', 't', 'i', 'o', 'n', ' ', 'D', 'o', 'c', 'u', 'm', 'e', 'n', 't', ' ', 'D', 'a', 't', 'e'),\n                                                                   ('N', 'u', 'm', 'b', 'e', 'r', ' ', 'o', 'f', ' ', 'E', 'x', 'i', 's', 't', 'i', 'n', 'g', ' ', 'S', 't', 'o', 'r', 'i', 'e', 's'),\n                                                                   ('N', 'u', 'm', 'b', 'e', 'r', ' ', 'o', 'f', ' ', 'P', 'r', 'o', 'p', 'o', 's', 'e', 'd', ' ', 'S', 't', 'o', 'r', 'i', 'e', 's'),\n                                                                                       ('P', 'e', 'r', 'm', 'i', 't', ' ', 'E', 'x', 'p', 'i', 'r', 'a', 't', 'i', 'o', 'n', ' ', 'D', 'a', 't', 'e'),\n                                                                                                                               ('E', 's', 't', 'i', 'm', 'a', 't', 'e', 'd', ' ', 'C ...
